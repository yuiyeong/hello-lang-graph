# %% [markdown]
# ## PDF 전처리
#
# - [소득세법](https://law.go.kr/lsSc.do?section=&menuId=1&subMenuId=15&tabMenuId=81&eventGubun=060101&query=%EC%86%8C%EB%93%9D%EC%84%B8%EB%B2%95#liBgcolor17) pdf 을 가지고 LangChain 의 Document 로 전처리해보기
# - PDF 를 파싱한 내용들 중 표, 서식, 이미지와 같은 것들이 제대로 가져왔는지를 확인해야한다.
# - 참고 자료
#     - [LangChain 의 공식 문서](https://python.langchain.com/docs/how_to/document_loader_pdf/)

# %%
import os


# tokenizers 내부 병렬화 유지 + 경고 억제; docling 에서 ocr 사용시의 warning 해결
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
from pathlib import Path


PDF_FILE_PATH = Path("../data/income-tax-law.pdf")

# %% [markdown]
# ### Docling 을 사용한 parsing
#
# - [공식 홈페이지](https://docling-project.github.io/docling/)
# - [Docling GitHub](https://github.com/docling-project/docling)
# - RAG 를 위한 PDF 파싱 라이브러리로 자세한 내용은 [이 문서](/docs/what-is-docling.md)를 참고
# - [LangChain 용 Docling 문서](https://python.langchain.com/docs/integrations/document_loaders/docling/#load)
#
# - DoclingLoader는 “변환 → 직렬화 →(선택) 청킹”을 한 번에 처리하는 편의 래퍼
#     - 변환은 문서를 구조화 모델(DoclingDocument)로 만드는 과정
#     - 직렬화는 그 구조화 모델을 Markdown/JSON 등 최종 포맷으로 내보내는 과정
#     - 청킹은 문서를 쪼개는 과정

# %% [markdown]
# ### 기본 설정으로 파싱

# %%
from langchain_docling import DoclingLoader


default_loader = DoclingLoader(file_path=PDF_FILE_PATH)
default_docs = default_loader.load()

print("총 Docling Document 개수:", len(default_docs))
default_docs[0]
# Out:
# 2025-09-20 15:43:06,658 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2025-09-20 15:43:06,682 - INFO - Going to convert document batch...
# 2025-09-20 15:43:06,683 - INFO - Initializing pipeline for StandardPdfPipeline with options hash e647edf348883bed75367b22fbe60347
# 2025-09-20 15:43:06,691 - WARNING - The plugin langchain_docling will not be loaded because Docling is being executed with allow_external_plugins=false.
# 2025-09-20 15:43:06,691 - INFO - Loading plugin 'docling_defaults'
# 2025-09-20 15:43:06,693 - INFO - Registered picture descriptions: ['vlm', 'api']
# 2025-09-20 15:43:06,701 - WARNING - The plugin langchain_docling will not be loaded because Docling is being executed with allow_external_plugins=false.
# 2025-09-20 15:43:06,701 - INFO - Loading plugin 'docling_defaults'
# 2025-09-20 15:43:06,709 - INFO - Registered ocr engines: ['easyocr', 'ocrmac', 'rapidocr', 'tesserocr', 'tesseract']
# 2025-09-20 15:43:14,706 - INFO - Accelerator device: 'mps'
# 2025-09-20 15:43:16,566 - INFO - Accelerator device: 'mps'
# 2025-09-20 15:43:17,684 - INFO - Accelerator device: 'mps'
# 2025-09-20 15:43:18,053 - INFO - Processing document income-tax-law.pdf
# 2025-09-20 15:44:31,183 - INFO - Finished converting document income-tax-law.pdf in 84.53 sec.
# Token indices sequence length is longer than the specified maximum sequence length for this model (594 > 512). Running this sequence through the model will result in indexing errors
# 총 Docling Document 개수: 2493
# Document(metadata={'source': PosixPath('../data/income-tax-law.pdf'), 'dl_meta': {'schema_name': 'docling_core.transforms.chunker.DocMeta', 'version': '1.0.0', 'doc_items': [{'self_ref': '#/texts/1', 'parent': {'$ref': '#/body'}, 'children': [], 'content_layer': 'body', 'label': 'text', 'prov': [{'page_no': 1, 'bbox': {'l': 30.0, 't': 660.18, 'r': 202.16, 'b': 651.203, 'coord_origin': 'BOTTOMLEFT'}, 'charspan': [0, 25]}]}, {'self_ref': '#/texts/2', 'parent': {'$ref': '#/body'}, 'children': [], 'content_layer': 'body', 'label': 'text', 'prov': [{'page_no': 1, 'bbox': {'l': 34.0, 't': 634.18, 'r': 564.72, 'b': 609.203, 'coord_origin': 'BOTTOMLEFT'}, 'charspan': [0, 105]}]}, {'self_ref': '#/texts/3', 'parent': {'$ref': '#/body'}, 'children': [], 'content_layer': 'body', 'label': 'text', 'prov': [{'page_no': 1, 'bbox': {'l': 50.0, 't': 602.18, 'r': 157.15, 'b': 593.203, 'coord_origin': 'BOTTOMLEFT'}, 'charspan': [0, 20]}]}], 'origin': {'mimetype': 'application/pdf', 'binary_hash': 10046112275470293943, 'filename': 'income-tax-law.pdf'}}}, page_content='제1장 총칙 <개정 2009. 12. 31.>\n제1조(목적) 이 법은 개인의 소득에 대하여 소득의 성격과 납세자의 부담능력 등에 따라 적정하게 과세함으로써 조세부 담의 형평을 도모하고 재정수입의 원활한 조달에 이바지함을 목적으로 한다.\n[본조신설 2009. 12. 31.]')

# %% [markdown]
# ### 커스텀 설정으로 파싱
#
# - 아래의 코드를 사용하기 위해선 시스템에 [tesseract](https://github.com/tesseract-ocr/tesseract) 와 한글, 한문 언어팩을 설치해야한다.

# %%
from docling.datamodel.base_models import InputFormat
from docling.datamodel.pipeline_options import PdfPipelineOptions, TesseractCliOcrOptions
from docling.document_converter import DocumentConverter, PdfFormatOption
from langchain_docling.loader import ExportType


# 1) 파이프라인 옵션: OCR + 테이블 구조 인식

pdf_opts = PdfPipelineOptions(
    do_table_structure=True,
    do_ocr=True,
)

# 2) OCR 엔진과 언어 설정(한국어+간체중국어)
pdf_opts.ocr_options = TesseractCliOcrOptions(lang=["kor", "chi_sim"])

# (표 정확도 향상) 셀 매칭 활성화
pdf_opts.table_structure_options.do_cell_matching = True

custom_loader = DoclingLoader(
    file_path=PDF_FILE_PATH,
    export_type=ExportType.MARKDOWN,
    converter=DocumentConverter(
        allowed_formats=[InputFormat.PDF],
        format_options={
            InputFormat.PDF: PdfFormatOption(pipeline_options=pdf_opts),
        },
    ),
)
custom_docs = custom_loader.load()

print("총 Docling Document 개수:", len(custom_docs))
# Out:
# 2025-09-20 15:44:43,960 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2025-09-20 15:44:43,966 - INFO - Going to convert document batch...
# 2025-09-20 15:44:43,967 - INFO - Initializing pipeline for StandardPdfPipeline with options hash 24bcc513fad89c13641d7803793186d2
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:44:44,046 - INFO - command: tesseract --list-langs
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:44:44,094 - INFO - Accelerator device: 'mps'
# 2025-09-20 15:44:45,200 - INFO - Accelerator device: 'mps'
# 2025-09-20 15:44:45,598 - INFO - Processing document income-tax-law.pdf
# 2025-09-20 15:44:49,602 - INFO - command: tesseract --psm 0 -l osd /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpjeu3hgpe.png stdout
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:44:49,977 - INFO - command: tesseract -l kor+chi_sim /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpjeu3hgpe.png stdout tsv
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:44:52,316 - INFO - command: tesseract --psm 0 -l osd /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpycanw7i0.png stdout
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:44:52,514 - INFO - command: tesseract -l kor+chi_sim /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpycanw7i0.png stdout tsv
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:44:53,003 - INFO - command: tesseract --psm 0 -l osd /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmp9e12xnm2.png stdout
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:44:53,142 - INFO - command: tesseract -l kor+chi_sim /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmp9e12xnm2.png stdout tsv
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:44:53,598 - INFO - command: tesseract --psm 0 -l osd /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmp8rino4xe.png stdout
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:44:53,726 - INFO - command: tesseract -l kor+chi_sim /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmp8rino4xe.png stdout tsv
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:44:54,915 - INFO - command: tesseract --psm 0 -l osd /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmp_w_38ddo.png stdout
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:44:55,113 - INFO - command: tesseract -l kor+chi_sim /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmp_w_38ddo.png stdout tsv
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:44:55,968 - INFO - command: tesseract --psm 0 -l osd /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmp40ymb1xi.png stdout
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:44:56,145 - INFO - command: tesseract -l kor+chi_sim /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmp40ymb1xi.png stdout tsv
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:44:58,021 - INFO - command: tesseract --psm 0 -l osd /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmphnlw5_bn.png stdout
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:44:58,260 - INFO - command: tesseract -l kor+chi_sim /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmphnlw5_bn.png stdout tsv
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:44:59,387 - INFO - command: tesseract --psm 0 -l osd /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpssp6yzb_.png stdout
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:44:59,552 - INFO - command: tesseract -l kor+chi_sim /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpssp6yzb_.png stdout tsv
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:00,245 - INFO - command: tesseract --psm 0 -l osd /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpbene2rhd.png stdout
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:00,427 - INFO - command: tesseract -l kor+chi_sim /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpbene2rhd.png stdout tsv
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:00,586 - INFO - command: tesseract --psm 0 -l osd /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpjpjb21kx.png stdout
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:00,807 - INFO - command: tesseract -l kor+chi_sim /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpjpjb21kx.png stdout tsv
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:04,345 - INFO - command: tesseract --psm 0 -l osd /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpjb4247mi.png stdout
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:04,716 - INFO - command: tesseract -l kor+chi_sim /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpjb4247mi.png stdout tsv
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:06,045 - INFO - command: tesseract --psm 0 -l osd /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpyuw0ua6o.png stdout
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:06,264 - INFO - command: tesseract -l kor+chi_sim /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpyuw0ua6o.png stdout tsv
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:08,218 - INFO - command: tesseract --psm 0 -l osd /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmp10qlmide.png stdout
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:08,437 - INFO - command: tesseract -l kor+chi_sim /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmp10qlmide.png stdout tsv
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:09,283 - INFO - command: tesseract --psm 0 -l osd /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpgk13gj8h.png stdout
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:09,419 - INFO - command: tesseract -l kor+chi_sim /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpgk13gj8h.png stdout tsv
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:11,526 - INFO - command: tesseract --psm 0 -l osd /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmp2gprpdip.png stdout
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:11,687 - INFO - command: tesseract -l kor+chi_sim /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmp2gprpdip.png stdout tsv
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:13,481 - INFO - command: tesseract --psm 0 -l osd /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpb1a5wahb.png stdout
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:13,660 - INFO - command: tesseract -l kor+chi_sim /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpb1a5wahb.png stdout tsv
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:15,903 - INFO - command: tesseract --psm 0 -l osd /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpilo3qqv6.png stdout
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:16,054 - INFO - command: tesseract -l kor+chi_sim /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpilo3qqv6.png stdout tsv
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:17,262 - INFO - command: tesseract --psm 0 -l osd /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpvgvysrr4.png stdout
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:17,428 - INFO - command: tesseract -l kor+chi_sim /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpvgvysrr4.png stdout tsv
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:18,353 - INFO - command: tesseract --psm 0 -l osd /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpg71gf9e9.png stdout
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:18,541 - INFO - command: tesseract -l kor+chi_sim /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpg71gf9e9.png stdout tsv
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:19,264 - INFO - command: tesseract --psm 0 -l osd /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmplh6avs_x.png stdout
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:19,519 - INFO - command: tesseract -l kor+chi_sim /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmplh6avs_x.png stdout tsv
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:23,036 - INFO - command: tesseract --psm 0 -l osd /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmplpcoexsy.png stdout
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:23,241 - INFO - command: tesseract -l kor+chi_sim /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmplpcoexsy.png stdout tsv
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:24,407 - INFO - command: tesseract --psm 0 -l osd /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpihg8xbf3.png stdout
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:24,655 - INFO - command: tesseract -l kor+chi_sim /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpihg8xbf3.png stdout tsv
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:26,245 - INFO - command: tesseract --psm 0 -l osd /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmplcikjspj.png stdout
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:26,522 - INFO - command: tesseract -l kor+chi_sim /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmplcikjspj.png stdout tsv
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:27,676 - INFO - command: tesseract --psm 0 -l osd /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmppgaga8nk.png stdout
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:27,846 - INFO - command: tesseract -l kor+chi_sim /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmppgaga8nk.png stdout tsv
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:28,233 - INFO - command: tesseract --psm 0 -l osd /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpc_u7_x8d.png stdout
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:28,358 - INFO - command: tesseract -l kor+chi_sim /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpc_u7_x8d.png stdout tsv
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:31,874 - INFO - command: tesseract --psm 0 -l osd /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpd64ydrh2.png stdout
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:32,257 - INFO - command: tesseract -l kor+chi_sim /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpd64ydrh2.png stdout tsv
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:33,612 - INFO - command: tesseract --psm 0 -l osd /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpr_g72bdc.png stdout
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:34,002 - INFO - command: tesseract -l kor+chi_sim /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpr_g72bdc.png stdout tsv
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:35,202 - INFO - command: tesseract --psm 0 -l osd /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpnrlx2kqe.png stdout
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:35,326 - INFO - command: tesseract -l kor+chi_sim /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpnrlx2kqe.png stdout tsv
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:35,835 - INFO - command: tesseract --psm 0 -l osd /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpup1u8vyb.png stdout
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:35,962 - INFO - command: tesseract -l kor+chi_sim /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpup1u8vyb.png stdout tsv
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:38,316 - INFO - command: tesseract --psm 0 -l osd /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpkv68zbn3.png stdout
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:38,451 - INFO - command: tesseract -l kor+chi_sim /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpkv68zbn3.png stdout tsv
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:39,221 - INFO - command: tesseract --psm 0 -l osd /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmp8k2tls1v.png stdout
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:39,395 - INFO - command: tesseract -l kor+chi_sim /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmp8k2tls1v.png stdout tsv
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:40,436 - INFO - command: tesseract --psm 0 -l osd /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmptdi7cxzm.png stdout
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:40,598 - INFO - command: tesseract -l kor+chi_sim /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmptdi7cxzm.png stdout tsv
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:41,113 - INFO - command: tesseract --psm 0 -l osd /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmp_8f_tub3.png stdout
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:41,296 - INFO - command: tesseract -l kor+chi_sim /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmp_8f_tub3.png stdout tsv
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:41,892 - INFO - command: tesseract --psm 0 -l osd /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpign08k8h.png stdout
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:42,053 - INFO - command: tesseract -l kor+chi_sim /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpign08k8h.png stdout tsv
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:44,075 - INFO - command: tesseract --psm 0 -l osd /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmp_1a75yd4.png stdout
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:44,251 - INFO - command: tesseract -l kor+chi_sim /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmp_1a75yd4.png stdout tsv
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:45,154 - INFO - command: tesseract --psm 0 -l osd /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpsmqe50ya.png stdout
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:45,287 - INFO - command: tesseract -l kor+chi_sim /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpsmqe50ya.png stdout tsv
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:49,484 - INFO - command: tesseract --psm 0 -l osd /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpsnbu9rlq.png stdout
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:45:49,619 - INFO - command: tesseract -l kor+chi_sim /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmpsnbu9rlq.png stdout tsv
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:46:11,306 - INFO - command: tesseract --psm 0 -l osd /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmp2798eui6.png stdout
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:46:11,647 - INFO - command: tesseract -l kor+chi_sim /var/folders/5s/8vb6wlwj325c_g2wy_5dq3ch0000gn/T/tmp2798eui6.png stdout tsv
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-09-20 15:46:21,220 - INFO - Finished converting document income-tax-law.pdf in 97.26 sec.
# 총 Docling Document 개수: 1

# %%
out_path = Path("../data/income-tax-law-parsed-by-docling.md")
with out_path.open("w", encoding="utf-8") as f:
    f.write(custom_docs[0].page_content)
